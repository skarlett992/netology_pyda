# %% [markdown]
# # Диплом

# %% [markdown]
# Проектная работа по модулю “Математика и статистика в Python”

# %% [markdown]
# 1.Загрузить файл hr.csv.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns
import statistics

# %matplotlib inline
url="hr.csv"
df=pd.read_csv(url)
df[:3]
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium

# %% [markdown]
# 2. Рассчитать основные статистики для переменных (среднее,медиана,мода,мин/макс,сред.отклонение).

# %%
last_evaluation = df['last_evaluation']
satisfaction_level = df['satisfaction_level']
fig, ax = plt.subplots()
ax.scatter(last_evaluation, satisfaction_level, c='red', alpha=0.3, edgecolors='none')

ax.grid(True)
plt.xlabel('last_evaluation')
plt.ylabel('satisfaction_level')
plt.show()

# %% [markdown]
# среднее последней оценки

# %%
statistics.mean(df['last_evaluation'])
sum(df['last_evaluation'])/len(df['last_evaluation'])
# Out:
# 0.7161017401159978

# %% [markdown]
# медиана последней оценки

# %%
print('Медиана: ', statistics.median(df['last_evaluation']))
# Out:
# Медиана:  0.72

# %% [markdown]
# мода

# %%
print('Значение моды: ', statistics.mode(last_evaluation))
# Out:
# Значение моды:  0.55

# %% [markdown]
# мин

# %%
min(last_evaluation)
# Out:
# 0.36

# %% [markdown]
# макс

# %%
max(last_evaluation)
# Out:
# 1.0

# %% [markdown]
# стандартное отклонение

# %%
df['last_evaluation'].std()
# Out:
# 0.17116911062327592

# %% [markdown]
# 3.Рассчитать и визуализировать корреляционную матрицу для переменных.

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(12,10)
plt.show()

# %% [markdown]
# 4.Визуализировать несколько взаимосвязей между переменными.

# %%
satisfaction_level = df['satisfaction_level']
left = df['left']
sns.regplot(x= satisfaction_level, y=left,data=df, fit_reg=True)
plt.xlabel('Уровень удовлетворенности')
plt.ylabel('Увольнение')
plt.title('Корреляционная зависимость двух выборок')
plt.grid(False)
plt.show()

# %%
Work_accident = df['Work_accident']
left = df['left']
sns.regplot(x= Work_accident, y=left,data=df, fit_reg=True)
plt.xlabel('Негативные происшествия на работе')
plt.ylabel('Увольнение')
plt.title('Корреляционная зависимость двух выборок')
plt.grid(False)
plt.show()

# %% [markdown]
# 5.С использованием t-test статистики проверить взаимосвязи между несколькими переменными.

# %%
female_bps = data['Satisfaction_level']['Last_evaliation']

male_bps = data[data['Dataset']>1]['Total_Bilirubin']

stats.ttest_ind(female_bps, male_bps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c9fe31d1135a> in <module>
# ----> 1 female_bps = data['Satisfaction_level']['Last_evaliation']
#       2
#       3 male_bps = data[data['Dataset']>1]['Total_Bilirubin']
#       4
#       5 stats.ttest_ind(female_bps, male_bps)
#
# NameError: name 'data' is not defined

# %% [markdown]
# 6.Рассчитать сколько работников работает в каждом департаменте.

# %%
df = pd.read_csv("hr.csv")
df.groupby(by='sales')['sales'].count()
# Out:
# sales
# IT             1227
# RandD           787
# accounting      767
# hr              739
# management      630
# marketing       858
# product_mng     902
# sales          4140
# support        2229
# technical      2720
# Name: sales, dtype: int64

# %% [markdown]
# 7.Показать распределение сотрудников по зарплатам.

# %%
df['salary'].value_counts()
df.groupby(by=[ 'salary'])['salary'].count()
# Out:
# salary
# high      1237
# low       7316
# medium    6446
# Name: salary, dtype: int64

# %% [markdown]
# 8.Показать распределение сотрудников по зарплатам совместно с департаментами.

# %%
df['salary'].value_counts()
df.groupby(by=['sales', 'salary'])['salary'].count()
# Out:
# sales        salary
# IT           high        83
#              low        609
#              medium     535
# RandD        high        51
#              low        364
#              medium     372
# accounting   high        74
#              low        358
#              medium     335
# hr           high        45
#              low        335
#              medium     359
# management   high       225
#              low        180
#              medium     225
# marketing    high        80
#              low        402
#              medium     376
# product_mng  high        68
#              low        451
#              medium     383
# sales        high       269
#              low       2099
#              medium    1772
# support      high       141
#              low       1146
#              medium     942
# technical    high       201
#              low       1372
#              medium    1147
# Name: salary, dtype: int64

# %% [markdown]
# 9.Сколько сотрудников покинули компанию.

# %%
df[df['left'] == 1].shape[0]
# Out:
# 3571

# %% [markdown]
# 10.Проверить несколько гипотез для данных, чтобы понять почему сотрудники покидают компанию.

# %% [markdown]
# 11.Загрузить результат (в формате .ipynb ноутбука) в репозиторий. Разместить ссылку на репозиторий в Личном кабинете
