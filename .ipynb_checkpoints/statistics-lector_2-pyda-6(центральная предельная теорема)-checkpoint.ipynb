# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
url='http://yustiks.ru/housing.csv'
s=requests.get(url).content
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(io.StringIO(s.decode('utf-8')),  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
#логнормальное распределение
sns.distplot(data['CRIM'])
plt.title('преступники на районе')
plt.show()

# %%
#геометрическое
sns.distplot(data['ZN'])
plt.title('пропорция жилых земель > 25кв фут')
plt.show()

# %%
#биноминальное
sns.distplot(data['INDUS'])
plt.title('доля предприятий не розничной торговли на 1 город')
plt.show()

# %%
#Бернулли
sns.distplot(data['CHAS'])
plt.title('Фиктивная переменная реки Charles')
plt.show()

# %%
sns.distplot(data['NOX'])
plt.title('This is the nitric oxides concentration (parts per 10 million)')
plt.show()

# %%
#нормальное
sns.distplot(data['RM'])
plt.title('This is the average number of rooms per dwelling')
plt.show()

# %%
#биноминальное
sns.distplot(data['AGE'])
plt.title('This is the proportion of owner-occupied units built prior to 1940')
plt.show()

# %%
#геометрическое
sns.distplot(data['DIS'])
plt.title('This is the weighted distances to five Boston employment centers')
plt.show()

# %%
#Биноминальное
sns.distplot(data['RAD'])
plt.title('This is the index of accessibility to radial highways')
plt.show()

# %%
sns.distplot(data['TAX'])
plt.title('This is the full-value property-tax rate per 10,000 dollars')
plt.show()

# %%
sns.distplot(data['PTRATIO'])
plt.title('This is the pupil-teacher ratio by town')
plt.show()

# %%
#логнормальное
sns.distplot(data['B'])
plt.title('This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town')
plt.show()

# %%
sns.distplot(data['LSTAT'])
plt.title('This is the percentage lower status of the population')
plt.show()

# %%
sns.distplot(data['MEDV'])
plt.title('Дома за 1000 к')
plt.show()

# %%
from IPython.display import Image

# Напишите код, который будет рисовать распределения попарно - точечные распределение
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
df=pd.read_csv(url)
s=requests.get(url).content
data=pd.read_csv(io.StringIO(s.decode('utf-8')))
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0

# %%
g = sns.pairplot(data)
# Out:
# /Users/natalaurina/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/natalaurina/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
#не получится засунуть в хью, тк нет категориального признака как у цветка ирис
fig = sns.pairplot(data=data[['Freedom', 'Corruption', 'Country (region)']], hue='Country (region)')
plt.show()
# Out:
# /Users/natalaurina/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/natalaurina/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/natalaurina/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:110: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     453     try:
# --> 454         bw = float(bw)
#     455     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-77b3d9cd2df6> in <module>
# ----> 1 fig = sns.pairplot(data=data[['Freedom', 'Corruption', 'Country (region)']], hue='Country (region)')
#       2 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2109             diag_kws.setdefault("shade", True)
#    2110             diag_kws["legend"] = False
# -> 2111             grid.map_diag(kdeplot, **diag_kws)
#    2112
#    2113     # Maybe plot on the off-diagonals
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
#    1401             self._clean_axis(ax)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     281         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     282                                            gridsize, cut, clip,
# --> 283                                            cumulative=cumulative)
#     284     else:
#     285         # Fall back to scipy if missing statsmodels
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     353     fft = kernel == "gau"
#     354     kde = smnp.KDEUnivariate(data)
# --> 355     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     356     if cumulative:
#     357         grid, y = kde.support, kde.cdf
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     140             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     141                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 142                     clip=clip, cut=cut)
#     143         else:
#     144             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     454         bw = float(bw)
#     455     except:
# --> 456         bw = bandwidths.select_bandwidth(X, bw, kern) # will cross-val fit this pattern?
#     457     bw *= adjust
#     458
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/bandwidths.py in select_bandwidth(x, bw, kernel)
#     170 #TODO: uncomment checks when we have non-rule of thumb bandwidths for diff. kernels
#     171 #    if kernel == "gauss":
# --> 172     return bandwidth_funcs[bw](x, kernel)
#     173 #    else:
#     174 #        raise ValueError("Only Gaussian Kernels are currently supported")
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/bandwidths.py in bw_scott(x, kernel)
#      53     A = _select_sigma(x)
#      54     n = len(x)
# ---> 55     return 1.059 * A * n ** (-0.2)
#      56
#      57 def bw_silverman(x, kernel=None):
#
# ZeroDivisionError: 0.0 cannot be raised to a negative power

# %% [markdown]
# Загрузить таблицу Happiness report. Нарисовать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0

# %%
X = data.drop(columns='Country (region)')
X.head()
# Out:
#    Ladder  SD of Ladder  Positive affect  Negative affect  Social support  \
# 0       1             4             41.0             10.0             2.0
# 1       2            13             24.0             26.0             4.0
# 2       3             8             16.0             29.0             3.0
# 3       4             9              3.0              3.0             1.0
# 4       5             1             12.0             25.0            15.0
#
#    Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0      5.0         4.0        47.0                    22.0
# 1      6.0         3.0        22.0                    14.0
# 2      3.0         8.0        11.0                     7.0
# 3      7.0        45.0         3.0                    15.0
# 4     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0

# %%
X.cov().round(2)
# Out:
#                            Ladder  SD of Ladder  Positive affect  \
# Ladder                    2041.00       1100.84           995.93
# SD of Ladder              1100.84       2041.00           173.69
# Positive affect            995.93        173.69          2015.00
# Negative affect           1061.21       1259.81           785.24
# Social support            1657.43       1219.52           778.33
# Freedom                   1108.09        512.36          1373.77
# Corruption                 370.87        506.90           405.29
# Generosity                1008.95        797.78           715.08
# Log of GDP\nper capita    1615.00       1254.53           586.12
# Healthy life\nexpectancy  1613.37       1208.03           647.91
#
#                           Negative affect  Social support  Freedom  \
# Ladder                            1061.21         1657.43  1108.09
# SD of Ladder                      1259.81         1219.52   512.36
# Positive affect                    785.24          778.33  1373.77
# Negative affect                   2015.00         1253.10   866.94
# Social support                    1253.10         2015.00   904.54
# Freedom                            866.94          904.54  2015.00
# Corruption                         309.23          230.74   736.27
# Generosity                         681.53          891.50   987.33
# Log of GDP\nper capita            1050.93         1509.29   800.93
# Healthy life\nexpectancy           944.80         1471.92   821.39
#
#                           Corruption  Generosity  Log of GDP\nper capita  \
# Ladder                        370.87     1008.95                 1615.00
# SD of Ladder                  506.90      797.78                 1254.53
# Positive affect               405.29      715.08                  586.12
# Negative affect               309.23      681.53                 1050.93
# Social support                230.74      891.50                 1509.29
# Freedom                       736.27      987.33                  800.93
# Corruption                   1837.67      511.33                  368.29
# Generosity                    511.33     2015.00                  949.02
# Log of GDP\nper capita        368.29      949.02                 1938.00
# Healthy life\nexpectancy      233.04      836.34                 1614.03
#
#                           Healthy life\nexpectancy
# Ladder                                     1613.37
# SD of Ladder                               1208.03
# Positive affect                             647.91
# Negative affect                             944.80
# Social support                             1471.92
# Freedom                                     821.39
# Corruption                                  233.04
# Generosity                                  836.34
# Log of GDP\nper capita                     1614.03
# Healthy life\nexpectancy                   1887.50

# %%
#np.cov(X)
#np.round_(np.cov(X), decimals=2)
#print(np.shape(np.cov(X)))
#np.round_(np.cov(X.T), decimals=2)
#standardized = (X - X.mean()) / X.std()
#np.round_(np.cov(standardized.T), decimals=2)
#np.round_(X.corr(), decimals=2)'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-eaa34f7c7a72> in <module>
# ----> 1 np.cov(X)
#       2 #np.round_(np.cov(X), decimals=2)
#       3 #print(np.shape(np.cov(X)))
#       4 #np.round_(np.cov(X.T), decimals=2)
#       5 #standardized = (X - X.mean()) / X.std()
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2425             w *= aweights
#    2426
# -> 2427     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2428     w_sum = w_sum[0]
#    2429
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in average(a, axis, weights, returned)
#     390
#     391     if weights is None:
# --> 392         avg = a.mean(axis)
#     393         scl = avg.dtype.type(a.size/avg.size)
#     394     else:
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      73             is_float16_result = True
#      74
# ---> 75     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      76     if isinstance(ret, mu.ndarray):
#      77         ret = um.true_divide(
#
# TypeError: can only concatenate str (not "float") to str

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop). Написать код.

# %%
pd.isnull(data['Country (region)']).sum()
# Out:
# 0

# %% [markdown]
# Сколько стран в выборке? Написать ответ. Можно ли сказать, что данные значения - это **проблема классификации**?

# %%
data['Country (region)'].nunique()
#много уникальных значений по каждому столбцу, поэтому нет
# Out:
# 156

# %% [markdown]
# Нарисовать sns.pairplot для класс - страна. Из графика сделать вывод о том, какие страны похожи.

# %%
# Если код ниже не работает, измените код, используя материал лекций. Пишите на почту, если испытываете проблемы: yustiks@gmail.com
sns.set(style="ticks", color_codes=True)
fig = sns.pairplot(data=data, hue='Country (region)')
plt.show()

# %% [markdown]
# Посчитать матрицу корреляций для таблицы. Написать код. Сделать график. Какие можно сделать выводы?

# %%
X.corr().round(2)
#многие признаки коррелируют между собой
# Out:
#                           Ladder  SD of Ladder  Positive affect  \
# Ladder                      1.00          0.54             0.49
# SD of Ladder                0.54          1.00             0.09
# Positive affect             0.49          0.09             1.00
# Negative affect             0.52          0.62             0.39
# Social support              0.82          0.60             0.39
# Freedom                     0.55          0.25             0.68
# Corruption                  0.19          0.26             0.21
# Generosity                  0.50          0.39             0.35
# Log of GDP\nper capita      0.81          0.63             0.30
# Healthy life\nexpectancy    0.82          0.61             0.33
#
#                           Negative affect  Social support  Freedom  \
# Ladder                               0.52            0.82     0.55
# SD of Ladder                         0.62            0.60     0.25
# Positive affect                      0.39            0.39     0.68
# Negative affect                      1.00            0.62     0.43
# Social support                       0.62            1.00     0.45
# Freedom                              0.43            0.45     1.00
# Corruption                           0.16            0.12     0.38
# Generosity                           0.34            0.44     0.49
# Log of GDP\nper capita               0.54            0.77     0.41
# Healthy life\nexpectancy             0.49            0.74     0.42
#
#                           Corruption  Generosity  Log of GDP\nper capita  \
# Ladder                          0.19        0.50                    0.81
# SD of Ladder                    0.26        0.39                    0.63
# Positive affect                 0.21        0.35                    0.30
# Negative affect                 0.16        0.34                    0.54
# Social support                  0.12        0.44                    0.77
# Freedom                         0.38        0.49                    0.41
# Corruption                      1.00        0.27                    0.20
# Generosity                      0.27        1.00                    0.48
# Log of GDP\nper capita          0.20        0.48                    1.00
# Healthy life\nexpectancy        0.12        0.43                    0.85
#
#                           Healthy life\nexpectancy
# Ladder                                        0.82
# SD of Ladder                                  0.61
# Positive affect                               0.33
# Negative affect                               0.49
# Social support                                0.74
# Freedom                                       0.42
# Corruption                                    0.12
# Generosity                                    0.43
# Log of GDP\nper capita                        0.85
# Healthy life\nexpectancy                      1.00

# %% [markdown]
# **Регрессионный анализ** - можно ли провести линейную зависимость между двумя выборками. Возьмем Ladder - удовлетворение жизнью, и generosity - доброта. Мы хотим найти прямую, которая разделит точки в пространстве наполовину. Это можно сделать графически. Нарисовать график. Можно ли сказать, что данная прямая является собственным вектором? При проецировании данных на эту прямую разброс данных максимален?

# %%
fig, ax = plt.subplots()
ax.scatter(df['Ladder'], df['Generosity'], c='red', alpha=0.3, edgecolors='none')

ax.grid(True)
plt.xlabel('Ladder')
plt.ylabel('Generosity')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')
from sklearn.preprocessing import StandardScaler

# Нормализуем данные
A = StandardScaler(with_std=False,copy=False).fit_transform(X)

fig = plt.figure(figsize=(10,10))
ax0 = fig.add_subplot(111)
ax0.set_aspect('equal')
ax0.set_xlim((-100,100))
ax0.set_ylim((-100,100))

ax0.scatter(A[:,0],A[:,1])


for i in range(len(A[:,0])):

    # строим прямую v
    v = np.array([3,2])
    ax0.plot(np.linspace(-100,100),np.linspace(-100,100)*(v[1]/v[0]),color='black',linestyle='--',linewidth=1.5)   

    # 2 выборки заданы в векторе A. Построим точку w из текущего значения двух выборок
    w = np.array([A[i][0],A[i][1]])

    # строим проекцию данной точки w на вектор v: cv
    cv = 0 + (np.dot(w,v))/np.dot(v,np.transpose(v))*v

    # линия между v и cv
    ax0.plot([w[0],cv[0]],[w[1],cv[1]],'r--',linewidth=1.5)


    # проверить результат
#    print(np.dot((w-cv),cv))
plt.xlabel('Первая выборка')
plt.ylabel('Вторая выборка')
plt.title('Проецирование двух выборок на прямую')
plt.show()

# %% [markdown]
# Можно ли сказать, что данная прямая является собственным вектором? - да
# При проецировании данных на эту прямую разброс данных максимален? - да

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
cubic=np.random.randint(1, 7, size=10)

#cubic = stats.binom.rvs(n=10,p=1/6,size=1)
ax = sns.distplot(cubic,
                  kde=False,
                  color='blue',
                  bins=6)
ax.set(xlabel='Биноминальное распределение', ylabel='Частота (плотность)')
# Out:
# [Text(0, 0.5, 'Частота (плотность)'),
#  Text(0.5, 0, 'Биноминальное распределение')]

# %% [markdown]
# Напишите код для моделирования 1000 подбрасываний игрального кубика. Начертите диаграму histogram.
# Почему график изменился? - график стал равномерным, потому что из-за гораздо большего количества попыток значения усреднились
# Как применить центральную предельную теорему? - ????(уточнить)

# %%
cubic2=np.random.randint(1, 7, size=1000)
ax = sns.distplot(cubic2,
                  kde=False,
                  color='blue',
                  bins=6)
ax.set(xlabel='Биноминальное распределение', ylabel='Частота (плотность)')
# Out:
# [Text(0, 0.5, 'Частота (плотность)'),
#  Text(0.5, 0, 'Биноминальное распределение')]
