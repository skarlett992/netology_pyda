# %% [markdown]
# ### Задание 1
#
# Получить интуицию, на что влияют параметры распределений. Построить по 5 функций плотностей с разными параметрами для каждого распределения: нормальное, экспоненциальное, Стьюдента на одном графике.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts

# %matplotlib inline

# %% [markdown]
# Параметр ```loc``` задаёт $\mu$, ```scale``` — среднеквадратичное отклонение $\sigma$, ```size``` — размер выборки. Имя параметра ```size``` при вызове функции ```rvs``` можно не писать.

# %%
list = [[2.0, 0.5],[3.0, 0.6], [4.0, 0.7], [5.0, 0.8]]
for mu, sigma in list:
    
    # зададим нормально распределенную случайную величину
    norm_rv = sts.norm(loc=mu, scale=sigma)
    
    # сгенерируем 10 значений
    norm_rv.rvs(size=10)    
    norm_rv.pdf(3)
    x = np.linspace(0,4,100)
    pdf = norm_rv.pdf(x)
    plt.plot(x, pdf)
    plt.ylabel('$F(x)$')
    plt.xlabel('$x$')
plt.show()

# %%
lams = [0.1, 0.2, 0.5, 0.7, 0.8]
for lam in lams:

    expon_rv = sts.expon(lam)

    expon_rv.rvs(10)
    x = np.linspace(0,5,100)
    cdf = expon_rv.cdf(x)
    plt.plot(x, cdf)

    plt.ylabel('$F(x)$')
    plt.xlabel('$x$')
plt.show()

# %%
n_list = [10, 100, 300, 500, 1000]
for n in n_list:
    t_rv = sts.t(n)

    t_rv.rvs(10)
    x = np.linspace(-5,5,1000)
    pdf = t_rv.pdf(x)
    plt.plot(x, pdf)

    plt.ylabel('$F(x)$')
    plt.xlabel('$x$')
plt.show()

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Непрерывная случайная величина задана плотностью распределения:
# $$ f(\xi) = C, x \in [0;5];f(\xi) = 0, x \notin [0;5]$$
# Найдите C, математическое ожидание $\xi$ а также вероятность попадания $\xi$ в отрезок $[3.5;7]$, т.е. $P(3.5<\xi<7)$.

# %% [markdown]
# 1) §(интеграл от 0 до 5)0-5 Cdx = 5C  C=1/5
#
#
# 2) m=5/2=2,5- мат ожидание
#
#
# 3) §3.5-5(интеграл от 3.5 до 5) от 1/5 = 5*1/5-3.5*1/5=1-0.7=0.3 - вероятность

# %% [markdown]
# ### Задание 3
# Известно, что светофор горит 54 секунды красным, 4 секунды жёлтым и 28 секунд зелёным. Посчитайте, какое количество информации несёт сообщение о цвете светофора в текущий момент. А что будет в случае 28, 28 и 28 секунд для каждого цвета?

# %%
import math
red = 54
yellow = 4
green = 28
all = red+yellow+green
yet_moment = (red/all)*math.log2(1/(red/all))+(yellow/all)*math.log2(1/(yellow/all))+(green/all)*math.log2(1/(green/all))
#равновероятные события:
equal_28 = math.log2(1/(1/3))

# %%
print(all, yet_moment, equal_28)
# Out:
# 86 1.154522162441165 1.584962500721156
