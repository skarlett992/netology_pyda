# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/math_netology_2/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Математики для data science.
# # Домашнее задание 2.

# %% [markdown]
# **Задание на отображение множеств.**

# %% [markdown]
# **Задание 1.**

# %% [markdown]
# Написать функцию отображения элементов одного множества в другое. Первое множество - художники, второе множество - картины художников.
# Множество художников - Серов, Левитан, Репин, Васнецов, Шишкин.
# Множество картин - "Утро в сосновом бору", "Богатыри", "Золотая осень", "Девочка с персиками", "Запорожцы", "Буралки на Волге", "Март", "Алёнушка".

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
artists = set(['Серов', 'Левитан', 'Репин', 'Васнецов', 'Шишкин'])
dict_actists = dict()
dict_actists['Шишкин'] = ['Утро в сосновом бору']
dict_actists['Левитан'] = ['Золотая осень', 'Март']
dict_actists['Репин'] = ['Запорожцы', 'Богатыри', 'Буралки на Волге']
dict_actists['Серов'] = ['Девочка с персиками']
dict_actists['Васнецов'] = ['Алёнушка']

# %%
for el in artists:
  pictures = ''
  for picture in dict_actists[el]:
    pictures += picture + ', '
  print(el + ': '+ pictures)
# Out:
# Левитан: Золотая осень, Март,
# Репин: Запорожцы, Богатыри, Буралки на Волге,
# Серов: Девочка с персиками,
# Шишкин: Утро в сосновом бору,
# Васнецов: Алёнушка,

# %% [markdown]
# **Полиномиальные функции.**

# %% [markdown]
# **Задание 2**. Найти из следующих функций те, которые являются полиномиальной функцией.

# %% [markdown]
# *  $$f(x)=\frac{1}{2}x^{6}-1\frac{5}{6}x+\frac{1}{3}$$
# *  $$f(x)=\frac{3x^{6}-11x+2}{6}$$
# *  $$f(x)=\frac{3x^{6}-11x+2}{6x}$$
# *  $$f(x)=x^{5}-3x^{2}+7x^{-2}$$
# *  $$f(x)=(5x^{2}-2)^3-\frac{1}{2}x^{3}$$
# *  $$f(x)=(1+\sqrt{x})^{3}-5(1+\sqrt{x})$$
# *  $$f(x)=\pi $$

# %% [markdown]
# Полиномиальными являются все вышеперечисленные функции за исключением последней

# %%
#как отразить дробь с целым остатком п первой функции???? - спросить
#(1+5/6)*x
from math import pow
def func(x):
  y = 1/2*pow(x, 6) - 1
  return y

# %% [markdown]
# **Задание 3**. Раскрыть скобки для следующего полинома $$(2x+1)^{2}(x-1)-x(4x^{2}-1)-x(4x^{2}-1)=ax^3+bx^2+cx+d$$ найти коэффициенты для a, b, c, d.

# %% [markdown]
# a=-4, b=-2, c=1, d=-1

# %% [markdown]
# Для данного задания полезно использовать следующие формулы сокращенного умножения:
# ![alt text](https://sun9-38.userapi.com/c851232/v851232044/19c5b0/7Yy6qz-MUHA.jpg)

# %% [markdown]
# Чему равна степень полинома? - трем

# %% [markdown]
# Нарисовать график для полинома.

# %%
def func(x):
  y = -4*pow(x, 3) - 2*pow(x, 2) + x - 1
  return y

# создаем вектор x
x1 = np.linspace(-3.0, 3.0, 100)
# на основе вектора x строим значения для вектора y
y1 = [func(x1[i]) for i in range(len(x1))]

plt.plot(x1, y1)
plt.title('График функции')
plt.ylabel('y')
plt.xlabel('x')

plt.show()

# %% [markdown]
# **Задание 3**.
# Для заданных функций найти подходящий график (не все функции имеют график):
# $\frac{3}{4}x-1$,  $\frac{3}{4}x+2$, $2-2x$, $2+2x$, $\frac{1}{4}(x+1)^{2}-2 $, $\frac{1}{4}(x-1)^2-2$, $(x-1)(x-3)$, $(x+1)(x+3)$, $2-x^2$, $2-\frac{1}{4}x^2$

# %%
# Рисунки: 1 ->'2-2x', 2 ->'2-x2'  , 3 ->'2-1/4*x2' , 4 ->'1/4(x+1)2-2' , 5 -> '3/4x-1', 6 ->(x-1)(x-3) 
def polynom1_(x, a):
    y = 2+a*x
    return y
def polynom2_(x, a):
    y = 2+a*pow(x, 2)
    return y
def polynom3_(x, a):
    y = 2+a*pow(x, 2)
    return y
def polynom4_(x, a):
    y = a*pow((x+1), 2) - 2
    return y
def polynom5_(x, a):
    y = a*x - 1
    return y
def polynom6_(x, a):
    y = a*(pow(x, 2)) - 4*x + 3
    return y


x1 = np.linspace(-30, 30, 100)
y1 = [polynom1_(x1[i], -2) for i in range(len(x1))]
y2 = [polynom2_(x1[i], -1/4) for i in range(len(x1))]
y3 = [polynom3_(x1[i], -1) for i in range(len(x1))]
y4 = [polynom4_(x1[i], 1/4) for i in range(len(x1))]
y5 = [polynom5_(x1[i], 3/4) for i in range(len(x1))]
y6 = [polynom6_(x1[i], 1) for i in range(len(x1))]


plt.figure(figsize=(10, 6))


plt.subplot(231)
plt.plot(x1,y1)
plt.ylim(-50, 50)
plt.title('y = 2-2x')

plt.subplot(232)
plt.plot(x1,y2)
plt.ylim(-200, 10)
plt.title('y = 2-1/4*x2')

plt.subplot(233)
plt.plot(x1,y3)
plt.ylim(-200, 20)
plt.title('y = $2-x^2$')

plt.subplot(234)
plt.plot(x1,y4)
plt.ylim(-20, 100)
plt.title('1/4(x+1)2-2')

plt.subplot(235)
plt.plot(x1,y5)
plt.ylim(-50, 50)
plt.title('3/4x-1')

plt.subplot(236)
plt.plot(x1,y6)
plt.ylim(-10, 100)
plt.title('(x-1)(x-3)')



plt.suptitle('Графики функций')
plt.show()

# %%
#далее функции, которых на рисунках не было
def polynom7_(x, a):
    y = a*x + 2
    return y
def polynom8_(x, a):
    y = 2+a*x
    return y
def polynom9_(x, a):
    y = a*pow((x-1), 2) - 2
    return y
def polynom10_(x, a):
    y = a*(pow(x, 2)) + 4*x + 3
    return y
x1 = np.linspace(-30, 30, 100)
#функции,которых не было на рисунках в задании:
y7 = [polynom7_(x1[i], 3/4) for i in range(len(x1))]
y8 = [polynom8_(x1[i], 2) for i in range(len(x1))]
y9 = [polynom9_(x1[i], 1) for i in range(len(x1))]
y10 = [polynom6_(x1[i], 1) for i in range(len(x1))]

plt.figure(figsize=(10, 6))
#функции, которых не было на рисунках:
plt.subplot(231)
plt.plot(x1,y7)
plt.ylim(-20, 100)
plt.title('3/4x-1')

plt.subplot(232)
plt.plot(x1,y8)
plt.ylim(-50, 50)
plt.title('y = 2+2x')

plt.subplot(233)
plt.plot(x1,y9)
plt.ylim(-10, 100)
plt.title('1/4(x-1)2-2')

plt.subplot(234)
plt.plot(x1,y10)
plt.ylim(-10, 100)
plt.title('(x+1)(x+3)')

plt.suptitle('Графики функций')
plt.show()

# %% [markdown]
# ![alt text](https://pp.userapi.com/c855532/v855532908/aadd4/uWjIZGDfw0s.jpg)

# %% [markdown]
# **Задание 4.** Найти минимальную степень следующего полинома:
#
# ![alt text](https://pp.userapi.com/c855532/v855532908/aadcd/PZdPYTQT02A.jpg)

# %% [markdown]
# там, где y = 0 , следовательно 0 - минимальная степень полинома

# %% [markdown]
# **Задания повышенного уровня**

# %% [markdown]
# Почему следующие функции не являются полиномиальными?
# $$y=5x^{-2}+1$$
# $$y=3x^{1/2}+2$$
# $$y=(5x+1)/(3x)$$

# %% [markdown]
# # потому что число n(наибольшее), указывающее на полином, может быть только натуральным

# %% [markdown]
# Найдите наибольшее и наименьшее значение функции $y = x^3 + 2x^2 + x + 3 $ на отрезке [-4;-1].

# %% [markdown]
# Найдем минимум и максимум функции.
#
# 1) сгенерируем отрезок, на котором будем искать минимум и максимум;
#
# 2) найдем значение функции на данном отрезке;
#
# 3) найдем минимум и максимум.

# %%
x = np.linspace(-4.0, -1.0, 100)
y = [x[i]**3 + 2*x[i]**2 + 3 for i in range(len(x))]
min_x = np.argmin(y)
print('x значение, при котором y минимально: ', x[min_x])
min_y = min(y)
print('минимальное значение функции: ', y[min_x])
max_x = np.argmax(y)
print('x значение, при котором y максимально: ', x[max_x])
print('максимальное значение функции: ', y[max_x])
# Out:
# x значение, при котором y минимально:  -4.0
# минимальное значение функции:  -29.0
# x значение, при котором y максимально:  -1.333333333333333
# максимальное значение функции:  4.185185185185185

# %% [markdown]
# Пример линейной регрессии - это применение полиномов на практике. В следующем примере дан датасет x, y, сгенерированный рандомно. Мы можем использовать линейную регрессию, чтобы предсказать значение переменной y от x.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression()
# написать линейную регрессию

plt.scatter(x, y, marker='o')
plt.title('Модель линейной регрессии')
plt.xlabel('2 - 3 * np.random.normal(0, 1, 20)')
plt.ylabel('x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)')
plt.show()

# %%
x = np.array(x).reshape(-1, 1)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lin_model = LinearRegression()
lin_model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = lin_model.predict(x)
plt.scatter(x, y, marker='o')
plt.scatter(x, y_predict, marker='x')
plt.title('Модель линейной регрессии')
plt.xlabel('2 - 3 * np.random.normal(0, 1, 20)')
plt.ylabel('x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)')
plt.legend(['исходные данные', 'полином 1ой степени'])
plt.show()

# %% [markdown]
# В данном примере найден полином первой степени. Как можно улучшить данную модель? Написать пример.

# %% [markdown]
# написать полиномиальную регрессию

# %%
from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 5) 
X_poly = poly.fit_transform(x) 
  
poly.fit(X_poly, y) 
lin2 = LinearRegression()
model = lin2.fit(X_poly, y) 
y_pred = model.predict(poly.fit_transform(x))
plt.scatter(x, y, marker='o')
plt.scatter(x, y_pred, marker='x')
plt.title('Модель линейной регрессии')
plt.xlabel('2 - 3 * np.random.normal(0, 1, 20)')
plt.ylabel('x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)')
plt.legend(['исходные данные', 'полином 5ой степени'])
plt.show()

# %%
poly = PolynomialFeatures(degree = 2) 
X_poly = poly.fit_transform(x) 
  
poly.fit(X_poly, y) 
lin2 = LinearRegression()
model = lin2.fit(X_poly, y) 
y_pred = model.predict(poly.fit_transform(x))
plt.scatter(x, y, marker='o')
plt.scatter(x, y_pred, marker='x')
plt.title('Модель линейной регрессии')
plt.xlabel('2 - 3 * np.random.normal(0, 1, 20)')
plt.ylabel('x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)')
plt.legend(['исходные данные', 'полином 2ой степени'])
plt.show()
