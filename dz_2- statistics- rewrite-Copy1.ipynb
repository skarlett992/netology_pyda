# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
url='http://yustiks.ru/housing.csv'
s=requests.get(url).content
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(io.StringIO(s.decode('utf-8')),  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
#логнормальное распределение
sns.distplot(data['CRIM'])
plt.title('преступники на районе')
plt.show()

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %%
#геометрическое
sns.distplot(data['ZN'])
plt.title('пропорция жилых земель > 25кв фут')
plt.show()

# %%
#биноминальное
sns.distplot(data['INDUS'])
plt.title('доля предприятий не розничной торговли на 1 город')
plt.show()

# %%
#Бернулли
sns.distplot(data['CHAS'])
plt.title('Фиктивная переменная реки Charles')
plt.show()

# %%
sns.distplot(data['NOX'])
plt.title('This is the nitric oxides concentration (parts per 10 million)')
plt.show()

# %%
#нормальное
sns.distplot(data['RM'])
plt.title('This is the average number of rooms per dwelling')
plt.show()

# %%
#биноминальное
sns.distplot(data['AGE'])
plt.title('This is the proportion of owner-occupied units built prior to 1940')
plt.show()

# %%
#геометрическое
sns.distplot(data['DIS'])
plt.title('This is the weighted distances to five Boston employment centers')
plt.show()

# %%
#Биноминальное
sns.distplot(data['RAD'])
plt.title('This is the index of accessibility to radial highways')
plt.show()

# %%
sns.distplot(data['TAX'])
plt.title('This is the full-value property-tax rate per 10,000 dollars')
plt.show()

# %%
sns.distplot(data['PTRATIO'])
plt.title('This is the pupil-teacher ratio by town')
plt.show()

# %%
#логнормальное
sns.distplot(data['B'])
plt.title('This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town')
plt.show()

# %%
sns.distplot(data['LSTAT'])
plt.title('This is the percentage lower status of the population')
plt.show()

# %%
sns.distplot(data['MEDV'])
plt.title('Дома за 1000 к')
plt.show()

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
from IPython.display import Image
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
df=pd.read_csv(url)
s=requests.get(url).content
data=pd.read_csv(io.StringIO(s.decode('utf-8')))
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
X = data.drop(columns='Country (region)')
X.head()
X.cov().round(2)
# Out:
#                            Ladder  SD of Ladder  Positive affect  \
# Ladder                    2041.00       1100.84           995.93
# SD of Ladder              1100.84       2041.00           173.69
# Positive affect            995.93        173.69          2015.00
# Negative affect           1061.21       1259.81           785.24
# Social support            1657.43       1219.52           778.33
# Freedom                   1108.09        512.36          1373.77
# Corruption                 370.87        506.90           405.29
# Generosity                1008.95        797.78           715.08
# Log of GDP\nper capita    1615.00       1254.53           586.12
# Healthy life\nexpectancy  1613.37       1208.03           647.91
#
#                           Negative affect  Social support  Freedom  \
# Ladder                            1061.21         1657.43  1108.09
# SD of Ladder                      1259.81         1219.52   512.36
# ...

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
df['Ladder'].fillna(0, inplace = True)
df['Positive affect'].fillna(0, inplace = True)
ladder = df['Ladder']
positive = df['Positive affect']
ladder = np.array(ladder).reshape(-1,1)
positive = np.array(positive).reshape(-1,1)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    ladder,
    positive,
    test_size = 0.2,
    random_state = 3
)
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted_y = model.predict(X_test)
model.score(X_test, y_test)
# Out:
# 0.31957186524163805

# %%
plt.xlabel('ladder')
plt.ylabel('positive affect')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(-50, 200, 100)
# Посчитаем предсказанные значения
y = model.coef_*x + model.intercept_
y = np.transpose(y)
plt.plot(x,y)
plt.plot(ladder, positive, 'r.')
plt.xlim(-50,200)
plt.ylim(-50,200)
plt.show()

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop). Написать код.

# %%
pd.isnull(data['Country (region)']).sum()
# Out:
# 0

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %%
data['Country (region)'].nunique()
# Out:
# 156

# %% [markdown]
# Добавить новую колонку в таблицу - 'continent'. Каждая страна относится к определенному материку. Всего материко 6:
# *   Евразия,
# *   Африка,
# *   Северная Америка,
# *   Южная Америка,
# *   Австралия,
# *   Антарктида.
#
# Таким образом, мы можем классифицировать каждый элемент как член определенного класса - континента.

# %%
continent=pd.read_csv('continents.csv')

continents=continent.rename(columns={"Two_Letter_Country_Code": "Code"}, )
continents=continents.drop(['Continent_Code', 'Country_Name', 'Three_Letter_Country_Code', 'Country_Number'], axis=1)
continents.loc[continents['Continent_Name'] == 'Asia','Continent_Name'] = 'Eurasia'
continents.loc[continents['Continent_Name'] == 'Europe','Continent_Name'] = 'Eurasia'
continents.loc[continents['Continent_Name'] == 'Oceania','Continent_Name'] = 'Australia'
continents.loc[continents['Continent_Name'] == 'Antarctica','Continent_Name'] = 'Antarctida'
continents.head()

#continents['Continent_Name'].nunique()
#pd.unique(continents['Contine_Name']).tolist()
# Out:
#   Continent_Name Code
# 0        Eurasia   AF
# 1        Eurasia   AL
# 2     Antarctida   AQ
# 3         Africa   DZ
# 4      Australia   AS

# %%
country_name=pd.read_csv('data.csv')
country_name.shape
country_name.head()
# Out:
#              Name Code
# 0     Afghanistan   AF
# 1   Åland Islands   AX
# 2         Albania   AL
# 3         Algeria   DZ
# 4  American Samoa   AS

# %%
names=country_name.join(continents.set_index('Code'), on='Code')
names=names.rename(columns={"Name": "Country (region)"})
names.head()
# Out:
#   Country (region) Code Continent_Name
# 0      Afghanistan   AF        Eurasia
# 1    Åland Islands   AX        Eurasia
# 2          Albania   AL        Eurasia
# 3          Algeria   DZ         Africa
# 4   American Samoa   AS      Australia

# %%
data=data.join(names.set_index('Country (region)'), on='Country (region)')
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy Code Continent_Name
# ...

# %%
#data.shape

data.drop_duplicates(subset=['Country (region)'], keep=False)
data['Country (region)'].nunique()
data=data.drop(['Code'], axis=1)
data=data.rename(columns={"Continent_Name": "Continent"}, )
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy Continent
# ...

# %% [markdown]
# Нарисовать sns.pairplot для класса - континет. Из графика сделать вывод о том, какие континеты похожи.

# %% [markdown]
# - из графиков видно, что между собой похожи Северная и Южная Америка

# %%
fig = sns.pairplot(data=data, hue='Continent')
plt.show()
# Out:
# /Users/natalaurina/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /Users/natalaurina/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %%
- можно сделать вывод, что на удоветворение жизнью (корреляция) сильно воздействуют социальная поддержка, продолжительность жизни, доброта
# Out:
#   File "<ipython-input-216-c8842bfb4575>", line 1
#     - можно сделать вывод, что на удоветворение жизнью (корреляция) сильно воздействуют социальная поддержка, продолжительность жизни, доброта
#                   ^
# SyntaxError: invalid syntax

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig1=plt.gcf()
fig1.set_size_inches(12,12)
plt.show()

# %% [markdown]
# **Регрессионный анализ** - можно ли провести линейную зависимость между двумя выборками. Возьмем Ladder - удовлетворение жизнью, и generosity - доброта. Мы хотим найти прямую, которая разделит точки в пространстве наполовину. Это можно сделать графически. Нарисовать график. Можно ли сказать, что данная прямая является собственным вектором? Сделать график регрессионной прямой на данных и собственных векторов.

# %%
fig, ax = plt.subplots()
ax.scatter(df['Ladder'], df['Generosity'], c='red', alpha=0.3, edgecolors='none')

ax.grid(True)
plt.xlabel('Ladder')
plt.ylabel('Generosity')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')
from sklearn.preprocessing import StandardScaler

# Нормализуем данные
A = StandardScaler(with_std=False,copy=False).fit_transform(X)

fig = plt.figure(figsize=(10,10))
ax0 = fig.add_subplot(111)
ax0.set_aspect('equal')
ax0.set_xlim((-100,100))
ax0.set_ylim((-100,100))

ax0.scatter(A[:,0],A[:,1])


for i in range(len(A[:,0])):

    # строим прямую v
    v = np.array([3,2])
    ax0.plot(np.linspace(-100,100),np.linspace(-100,100)*(v[1]/v[0]),color='black',linestyle='--',linewidth=1.5)   

    # 2 выборки заданы в векторе A. Построим точку w из текущего значения двух выборок
    w = np.array([A[i][0],A[i][1]])

    # строим проекцию данной точки w на вектор v: cv
    cv = 0 + (np.dot(w,v))/np.dot(v,np.transpose(v))*v

    # линия между v и cv
    ax0.plot([w[0],cv[0]],[w[1],cv[1]],'r--',linewidth=1.5)


    # проверить результат
#    print(np.dot((w-cv),cv))
plt.xlabel('Первая выборка')
plt.ylabel('Вторая выборка')
plt.title('Проецирование двух выборок на прямую')
plt.show()

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
cubic=np.random.randint(1, 7, size=10)

#cubic = stats.binom.rvs(n=10,p=1/6,size=1)
ax = sns.distplot(cubic,
                  kde=False,
                  color='blue',
                  bins=6)
ax.set(xlabel='Биноминальное распределение', ylabel='Частота (плотность)')
# Out:
# [Text(0, 0.5, 'Частота (плотность)'),
#  Text(0.5, 0, 'Биноминальное распределение')]

# %% [markdown]
# моделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему?

# %% [markdown]
# -поскольку подбрасываний уже не 10, а 1000 по 100, график демонстрирует подчинение закону больших чисел (ЦПТ) и от случая уже мало что зависит

# %%
cubic2=np.random.randint(1, 7, size=1000)
ax = sns.distplot(cubic2,
                  kde=False,
                  color='blue',
                  bins=6)
ax.set(xlabel='Биноминальное распределение', ylabel='Частота (плотность)')
# Out:
# [Text(0, 0.5, 'Частота (плотность)'),
#  Text(0.5, 0, 'Биноминальное распределение')]
